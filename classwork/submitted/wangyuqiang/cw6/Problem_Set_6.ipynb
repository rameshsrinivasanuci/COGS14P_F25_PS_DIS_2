# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select  **Restart** and **Clear All Outputs**, then select **Run All**).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Yuqiang Wang"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Problem Set 6
# ### This is a problem set.  You can work on it with the help of your classmates, Google, or ask me any questions you would like.
# ### This problem set is take home.

# %%
import numpy as np
from numpy import random 
rng = random.default_rng(seed = 121)
from sound import pop_scales, make_tone, play_sound

# %% [markdown]
# 1. Write a function **play_scale** that makes and plays the **first five notes** composing one octave in either ascending or descending order.
#
# I have imported all the functions in sound.py so you can call them.  If you are not able to, its because sound.py is not in the same folder as this assignment.
#
# The function `pop_scale()` in the module `sound` returns a dictionary with all the frequencies. You can get a list of all the frequencies in the first octave using the keyword 'frequencies'
#
# The first note A has a frequency of 440 in the first octave. In the second octave at 880, and all the other frequencies also double. The third octave starts at double that frequency or 1760 (4*440), and all the other frequencies are multiplied by 4.  So for any note we can get the equivalent frequency at any octave using
#
#     frequency = frequency*2**(n_octave-1)
#
#
# The function **play_scale** should have four input arguments, one is the octave (**n_octave**), the second is the **duration** of each note, and the third is an optional **volume** which defaults to 0.05, and the fourth is an optional order which is a string which is either 'ascend' or 'descend', and defaults to 'ascend'. If an invalid order is given it should not play anything and should print out "Invalid Order"

# %%
def play_scale(n_octave, duration, volume=0.05, order='ascend'):
    scales = pop_scales()
    freqs = scales['frequencies'] 
    freqs = freqs[0:5]
    freqs = [f * 2**(n_octave - 1) for f in freqs]
    if order == 'ascend':
        for f in freqs:
            tone = make_tone(f, duration)
            play_sound(tone, volume=volume)
    elif order == 'descend':
        for f in reversed(freqs):
            tone = make_tone(f, duration)
            play_sound(tone, volume=volume)
    else:
        print("Invalid Order")

# %%
#should play ascending order 2nd octave
play_scale(2,0.5)
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 #should play ascending order 2nd octave
# ----> 2 play_scale(2,0.5)
#
# Cell In[5], line 9, in play_scale(n_octave, duration, volume, order)
#       7     for f in freqs:
#       8         tone = make_tone(f, duration)
# ----> 9         play_sound(tone, volume=volume)
#      10 elif order == 'descend':
#      11     for f in reversed(freqs):
#
# File ~/sound.py:46, in play_sound(sample, volume, samplingrate, block)
#      44 sample = 32767*sample # scale to the range of the sound card.
#      45 sample  = sample.astype(np.int16) # convert to 16 bit integers.
# ---> 46 sd.play(sample, samplingrate, blocking=block)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:178, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     175     ctx.write_outdata(outdata)
#     176     ctx.callback_exit()
# --> 178 ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     179                  ctx.output_dtype, callback, blocking,
#     180                  prime_output_buffers_using_stream_callback=False,
#     181                  **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2653, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2650 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2651                  blocking, **kwargs):
#    2652     stop()  # Stop previous playback/recording
# -> 2653     self.stream = StreamClass(samplerate=samplerate,
#    2654                               channels=channels,
#    2655                               dtype=dtype,
#    2656                               callback=callback,
#    2657                               finished_callback=self.finished_callback,
#    2658                               **kwargs)
#    2659     self.stream.start()
#    2660     global _last_callback
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:1527, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1495 def __init__(self, samplerate=None, blocksize=None,
#    1496              device=None, channels=None, dtype=None, latency=None,
#    1497              extra_settings=None, callback=None, finished_callback=None,
#    1498              clip_off=None, dither_off=None, never_drop_input=None,
#    1499              prime_output_buffers_using_stream_callback=None):
#    1500     """PortAudio output stream (using NumPy).
#    1501
#    1502     This has the same methods and attributes as `Stream`, except
#    (...)
#    1525
#    1526     """
# -> 1527     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1528                          **_remove_self(locals()))
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:828, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     825         samplerate = isamplerate
#     826 else:
#     827     parameters, self._dtype, self._samplesize, samplerate = \
# --> 828         _get_stream_parameters(kind, device, channels, dtype, latency,
#     829                                extra_settings, samplerate)
#     830     self._device = parameters.device
#     831     self._channels = parameters.channelCount
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2735, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2732 if samplerate is None:
#    2733     samplerate = default.samplerate
# -> 2735 info = query_devices(device)
#    2736 if channels is None:
#    2737     channels = info['max_' + kind + '_channels']
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:572, in query_devices(device, kind)
#     570 info = _lib.Pa_GetDeviceInfo(device)
#     571 if not info:
# --> 572     raise PortAudioError(f'Error querying device {device}')
#     573 assert info.structVersion == 2
#     574 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1

# %%
#should play descending order 1st octave
play_scale(1,0.5,order='descend')
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 #should play descending order 1st octave
# ----> 2 play_scale(1,0.5,order='descend')
#
# Cell In[5], line 13, in play_scale(n_octave, duration, volume, order)
#      11     for f in reversed(freqs):
#      12         tone = make_tone(f, duration)
# ---> 13         play_sound(tone, volume=volume)
#      14 else:
#      15     print("Invalid Order")
#
# File ~/sound.py:46, in play_sound(sample, volume, samplingrate, block)
#      44 sample = 32767*sample # scale to the range of the sound card.
#      45 sample  = sample.astype(np.int16) # convert to 16 bit integers.
# ---> 46 sd.play(sample, samplingrate, blocking=block)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:178, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     175     ctx.write_outdata(outdata)
#     176     ctx.callback_exit()
# --> 178 ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     179                  ctx.output_dtype, callback, blocking,
#     180                  prime_output_buffers_using_stream_callback=False,
#     181                  **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2653, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2650 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2651                  blocking, **kwargs):
#    2652     stop()  # Stop previous playback/recording
# -> 2653     self.stream = StreamClass(samplerate=samplerate,
#    2654                               channels=channels,
#    2655                               dtype=dtype,
#    2656                               callback=callback,
#    2657                               finished_callback=self.finished_callback,
#    2658                               **kwargs)
#    2659     self.stream.start()
#    2660     global _last_callback
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:1527, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1495 def __init__(self, samplerate=None, blocksize=None,
#    1496              device=None, channels=None, dtype=None, latency=None,
#    1497              extra_settings=None, callback=None, finished_callback=None,
#    1498              clip_off=None, dither_off=None, never_drop_input=None,
#    1499              prime_output_buffers_using_stream_callback=None):
#    1500     """PortAudio output stream (using NumPy).
#    1501
#    1502     This has the same methods and attributes as `Stream`, except
#    (...)
#    1525
#    1526     """
# -> 1527     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1528                          **_remove_self(locals()))
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:828, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     825         samplerate = isamplerate
#     826 else:
#     827     parameters, self._dtype, self._samplesize, samplerate = \
# --> 828         _get_stream_parameters(kind, device, channels, dtype, latency,
#     829                                extra_settings, samplerate)
#     830     self._device = parameters.device
#     831     self._channels = parameters.channelCount
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2735, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2732 if samplerate is None:
#    2733     samplerate = default.samplerate
# -> 2735 info = query_devices(device)
#    2736 if channels is None:
#    2737     channels = info['max_' + kind + '_channels']
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:572, in query_devices(device, kind)
#     570 info = _lib.Pa_GetDeviceInfo(device)
#     571 if not info:
# --> 572     raise PortAudioError(f'Error querying device {device}')
#     573 assert info.structVersion == 2
#     574 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1

# %%
#should play descending order louder volume 
play_scale(2,0.5,volume = 0.15,order='descend')
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 #should play descending order louder volume
# ----> 2 play_scale(2,0.5,volume = 0.15,order='descend')
#
# Cell In[5], line 13, in play_scale(n_octave, duration, volume, order)
#      11     for f in reversed(freqs):
#      12         tone = make_tone(f, duration)
# ---> 13         play_sound(tone, volume=volume)
#      14 else:
#      15     print("Invalid Order")
#
# File ~/sound.py:46, in play_sound(sample, volume, samplingrate, block)
#      44 sample = 32767*sample # scale to the range of the sound card.
#      45 sample  = sample.astype(np.int16) # convert to 16 bit integers.
# ---> 46 sd.play(sample, samplingrate, blocking=block)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:178, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     175     ctx.write_outdata(outdata)
#     176     ctx.callback_exit()
# --> 178 ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     179                  ctx.output_dtype, callback, blocking,
#     180                  prime_output_buffers_using_stream_callback=False,
#     181                  **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2653, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2650 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2651                  blocking, **kwargs):
#    2652     stop()  # Stop previous playback/recording
# -> 2653     self.stream = StreamClass(samplerate=samplerate,
#    2654                               channels=channels,
#    2655                               dtype=dtype,
#    2656                               callback=callback,
#    2657                               finished_callback=self.finished_callback,
#    2658                               **kwargs)
#    2659     self.stream.start()
#    2660     global _last_callback
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:1527, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1495 def __init__(self, samplerate=None, blocksize=None,
#    1496              device=None, channels=None, dtype=None, latency=None,
#    1497              extra_settings=None, callback=None, finished_callback=None,
#    1498              clip_off=None, dither_off=None, never_drop_input=None,
#    1499              prime_output_buffers_using_stream_callback=None):
#    1500     """PortAudio output stream (using NumPy).
#    1501
#    1502     This has the same methods and attributes as `Stream`, except
#    (...)
#    1525
#    1526     """
# -> 1527     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1528                          **_remove_self(locals()))
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:828, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     825         samplerate = isamplerate
#     826 else:
#     827     parameters, self._dtype, self._samplesize, samplerate = \
# --> 828         _get_stream_parameters(kind, device, channels, dtype, latency,
#     829                                extra_settings, samplerate)
#     830     self._device = parameters.device
#     831     self._channels = parameters.channelCount
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2735, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2732 if samplerate is None:
#    2733     samplerate = default.samplerate
# -> 2735 info = query_devices(device)
#    2736 if channels is None:
#    2737     channels = info['max_' + kind + '_channels']
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:572, in query_devices(device, kind)
#     570 info = _lib.Pa_GetDeviceInfo(device)
#     571 if not info:
# --> 572     raise PortAudioError(f'Error querying device {device}')
#     573 assert info.structVersion == 2
#     574 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1

# %%
#should not play anything and should print "Invalid Order"
play_scale(2,0.5,order = 'x')
# Out:
# Invalid Order

# %% [markdown]
# 2. Make a function **random_scales** which randomly plays an ascending or descending scale in a random octave chosen from the first, second or 3rd octave.
#
# - You should make use of **play_scale** that you created in problem 1.
#
# - **random_scale** should get as input arguments the **duration**, and an optional parameters for volume which defaults to 0.05.
#
# - It should choose **n_octave** randomly from 1,2,3.
#
# - The function should play the scale and return a string with the type of scale of played, 'ascend' or 'descend'
#
# - The function should also return which octave was played
#
# Hint: use the random number generator `rng` to randomly select the type of scale and octave to play

# %%
def random_scale(duration, volume=0.05):
    n_oct = rng.integers(1, 4)
    
    order = rng.choice(['ascend', 'descend'])
    
    play_scale(n_oct, duration, volume, order)
    
    return order, n_oct

# %%
rng = random.default_rng(seed = 1211)
order, n_oct = random_scale(0.5,0.2)
assert n_oct in [1,2,3]
assert order in ['ascend','descend']
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 rng = random.default_rng(seed = 1211)
# ----> 2 order, n_oct = random_scale(0.5,0.2)
#       3 assert n_oct in [1,2,3]
#       4 assert order in ['ascend','descend']
#
# Cell In[10], line 6, in random_scale(duration, volume)
#       2 n_oct = rng.integers(1, 4)
#       4 order = rng.choice(['ascend', 'descend'])
# ----> 6 play_scale(n_oct, duration, volume, order)
#       8 return order, n_oct
#
# Cell In[5], line 9, in play_scale(n_octave, duration, volume, order)
#       7     for f in freqs:
#       8         tone = make_tone(f, duration)
# ----> 9         play_sound(tone, volume=volume)
#      10 elif order == 'descend':
#      11     for f in reversed(freqs):
#
# File ~/sound.py:46, in play_sound(sample, volume, samplingrate, block)
#      44 sample = 32767*sample # scale to the range of the sound card.
#      45 sample  = sample.astype(np.int16) # convert to 16 bit integers.
# ---> 46 sd.play(sample, samplingrate, blocking=block)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:178, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     175     ctx.write_outdata(outdata)
#     176     ctx.callback_exit()
# --> 178 ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     179                  ctx.output_dtype, callback, blocking,
#     180                  prime_output_buffers_using_stream_callback=False,
#     181                  **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2653, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2650 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2651                  blocking, **kwargs):
#    2652     stop()  # Stop previous playback/recording
# -> 2653     self.stream = StreamClass(samplerate=samplerate,
#    2654                               channels=channels,
#    2655                               dtype=dtype,
#    2656                               callback=callback,
#    2657                               finished_callback=self.finished_callback,
#    2658                               **kwargs)
#    2659     self.stream.start()
#    2660     global _last_callback
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:1527, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1495 def __init__(self, samplerate=None, blocksize=None,
#    1496              device=None, channels=None, dtype=None, latency=None,
#    1497              extra_settings=None, callback=None, finished_callback=None,
#    1498              clip_off=None, dither_off=None, never_drop_input=None,
#    1499              prime_output_buffers_using_stream_callback=None):
#    1500     """PortAudio output stream (using NumPy).
#    1501
#    1502     This has the same methods and attributes as `Stream`, except
#    (...)
#    1525
#    1526     """
# -> 1527     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1528                          **_remove_self(locals()))
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:828, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     825         samplerate = isamplerate
#     826 else:
#     827     parameters, self._dtype, self._samplesize, samplerate = \
# --> 828         _get_stream_parameters(kind, device, channels, dtype, latency,
#     829                                extra_settings, samplerate)
#     830     self._device = parameters.device
#     831     self._channels = parameters.channelCount
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2735, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2732 if samplerate is None:
#    2733     samplerate = default.samplerate
# -> 2735 info = query_devices(device)
#    2736 if channels is None:
#    2737     channels = info['max_' + kind + '_channels']
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:572, in query_devices(device, kind)
#     570 info = _lib.Pa_GetDeviceInfo(device)
#     571 if not info:
# --> 572     raise PortAudioError(f'Error querying device {device}')
#     573 assert info.structVersion == 2
#     574 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1

# %% [markdown]
# 3. Copy and paste your function from Problem Set 5, **get_response** that queries the subject with a prompt and checks if the response is among the correct keys. They should be prompted to respond again if they type any other key. You may use my function from the answer key.

# %%
def get_response(prompt, valid_keys):
    response = input(prompt)
    
    while response not in valid_keys:
        print("Invalid response. Please try again.")
        response = input(prompt)
    
    return response

# %% [markdown]
# 4. Write a function called **trial** that uses **random_scale** and **get_response** to play a random scale, then ask for a response of a for ascending and d for descending.
#
# The subject should response with they key `a` for ascending and `d` for descending.  A good prompt might be
#
#         'Respond a for ascending and d for descending: '
#
# The function should evaluate if the response is correct or incorrect and create a variable **accuracy** which is 1 if they get it right and 0 if they get it wrong.
#
# The function should return **accuracy**, **response**, and **order**
#
# The input arguments for trial are **duration** and **volume**.  **volume** should have a default value of 0.05.

# %%
def trial(duration, volume=0.05):
    order, n_oct = random_scale(duration, volume)
    
    prompt = "Respond a for ascending and d for descending: "
    response = get_response(prompt, ['a', 'd'])
    
    # ascend → a
    # descend → d
    if (order == 'ascend' and response == 'a') or \
       (order == 'descend' and response == 'd'):
        accuracy = 1
    else:
        accuracy = 0
    
    return accuracy, response, order

# %%
accuracy, response, order = trial(0.5)
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 accuracy, response, order = trial(0.5)
#       2 print(accuracy)
#
# Cell In[13], line 2, in trial(duration, volume)
#       1 def trial(duration, volume=0.05):
# ----> 2     order, n_oct = random_scale(duration, volume)
#       4     prompt = "Respond a for ascending and d for descending: "
#       5     response = get_response(prompt, ['a', 'd'])
#
# Cell In[10], line 6, in random_scale(duration, volume)
#       2 n_oct = rng.integers(1, 4)
#       4 order = rng.choice(['ascend', 'descend'])
# ----> 6 play_scale(n_oct, duration, volume, order)
#       8 return order, n_oct
#
# Cell In[5], line 13, in play_scale(n_octave, duration, volume, order)
#      11     for f in reversed(freqs):
#      12         tone = make_tone(f, duration)
# ---> 13         play_sound(tone, volume=volume)
#      14 else:
#      15     print("Invalid Order")
#
# File ~/sound.py:46, in play_sound(sample, volume, samplingrate, block)
#      44 sample = 32767*sample # scale to the range of the sound card.
#      45 sample  = sample.astype(np.int16) # convert to 16 bit integers.
# ---> 46 sd.play(sample, samplingrate, blocking=block)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:178, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     175     ctx.write_outdata(outdata)
#     176     ctx.callback_exit()
# --> 178 ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     179                  ctx.output_dtype, callback, blocking,
#     180                  prime_output_buffers_using_stream_callback=False,
#     181                  **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2653, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2650 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2651                  blocking, **kwargs):
#    2652     stop()  # Stop previous playback/recording
# -> 2653     self.stream = StreamClass(samplerate=samplerate,
#    2654                               channels=channels,
#    2655                               dtype=dtype,
#    2656                               callback=callback,
#    2657                               finished_callback=self.finished_callback,
#    2658                               **kwargs)
#    2659     self.stream.start()
#    2660     global _last_callback
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:1527, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1495 def __init__(self, samplerate=None, blocksize=None,
#    1496              device=None, channels=None, dtype=None, latency=None,
#    1497              extra_settings=None, callback=None, finished_callback=None,
#    1498              clip_off=None, dither_off=None, never_drop_input=None,
#    1499              prime_output_buffers_using_stream_callback=None):
#    1500     """PortAudio output stream (using NumPy).
#    1501
#    1502     This has the same methods and attributes as `Stream`, except
#    (...)
#    1525
#    1526     """
# -> 1527     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1528                          **_remove_self(locals()))
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:828, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     825         samplerate = isamplerate
#     826 else:
#     827     parameters, self._dtype, self._samplesize, samplerate = \
# --> 828         _get_stream_parameters(kind, device, channels, dtype, latency,
#     829                                extra_settings, samplerate)
#     830     self._device = parameters.device
#     831     self._channels = parameters.channelCount
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2735, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2732 if samplerate is None:
#    2733     samplerate = default.samplerate
# -> 2735 info = query_devices(device)
#    2736 if channels is None:
#    2737     channels = info['max_' + kind + '_channels']
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:572, in query_devices(device, kind)
#     570 info = _lib.Pa_GetDeviceInfo(device)
#     571 if not info:
# --> 572     raise PortAudioError(f'Error querying device {device}')
#     573 assert info.structVersion == 2
#     574 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1
